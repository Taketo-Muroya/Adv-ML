# %% [markdown]
# # Boston Housing Prices Keras Example With Preprocessing.

# %% [markdown]
# # Obtaining the Boston Housing Prices dataset

# %%
! pip install scikit-learn --upgrade # load newest version of sklearn
# Out:
# Requirement already up-to-date: scikit-learn in /usr/local/lib/python3.6/dist-packages (0.22.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.11.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.17.5)
# Requirement already satisfied, skipping upgrade: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (0.14.1)
# Requirement already satisfied, skipping upgrade: scipy>=0.17.0 in /usr/local/lib/python3.6/dist-packages (from scikit-learn) (1.4.1)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

boston = datasets.load_boston()
X = pd.DataFrame(boston.data)

X.columns= boston.feature_names
y = boston.target
X.head(2)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX  ...  RAD    TAX  PTRATIO      B  LSTAT
# 0  0.00632  18.0   2.31   0.0  0.538  ...  1.0  296.0     15.3  396.9   4.98
# 1  0.02731   0.0   7.07   0.0  0.469  ...  2.0  242.0     17.8  396.9   9.14
#
# [2 rows x 13 columns]

# %% [markdown]
# # Build a model to predict diabetes disease progression

# %%
# Set up training and test data
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

print(X_train.shape)
print(y_train.shape)
print(X.columns.tolist())
# Out:
# (379, 13)
# (379,)
# ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT']

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# We create the preprocessing pipelines for both numeric and categorical data.
numeric_features = ['CRIM', 'ZN', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS',  'TAX', 'PTRATIO', 'B', 'LSTAT']
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['CHAS', 'RAD']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])


#Fit your preprocessor object
prediction_input_preprocessor=preprocessor.fit(X_train) 

import pickle
pickle.dump(prediction_input_preprocessor, open( "preprocessor.pkl", "wb" ) )

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer

#Simple example using make_column_transformer:
#make_column_transformer is a shorthand for the ColumnTransformer constructor; it does not require, 
#and does not permit, naming the transformers. Instead, they will be given names automatically based on their types. 


# Treating all variables as if they were continuous for example only.
features_to_transform=X.columns
preprocess = make_column_transformer(
    (StandardScaler(),features_to_transform)
)

#Fit your preprocessor object
prediction_input_preprocessor=preprocess.fit(X_train) 

import pickle
pickle.dump(prediction_input_preprocessor, open( "preprocessor.pkl", "wb" ) )

# %%
# Check shape for keras input:
prediction_input_preprocessor.transform(X_train).shape
# Out:
# (379, 22)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import keras
from keras.optimizers import SGD
model = Sequential()
model.add(Dense(32, input_dim=22, activation='relu'))
model.add(Dense(32, activation='relu'))

model.add(Dense(1))
# Compile model
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# Fitting the ANN to the Training set
model.fit(prediction_input_preprocessor.transform(X_train),y_train, 
               batch_size = 60, 
               epochs = 300, verbose=2)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Epoch 1/300
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
#  - 1s - loss: 622.0227 - mean_squared_error: 622.0227
# Epoch 2/300
#  - 0s - loss: 604.4801 - mean_squared_error: 604.4801
# Epoch 3/300
#  - 0s - loss: 587.6081 - mean_squared_error: 587.6081
# Epoch 4/300
#  - 0s - loss: 570.6110 - mean_squared_error: 570.6110
# Epoch 5/300
#  - 0s - loss: 552.3511 - mean_squared_error: 552.3511
# Epoch 6/300
#  - 0s - loss: 533.0730 - mean_squared_error: 533.0730
# Epoch 7/300
#  - 0s - loss: 510.9110 - mean_squared_error: 510.9110
# Epoch 8/300
#  - 0s - loss: 485.0613 - mean_squared_error: 485.0613
# Epoch 9/300
#  - 0s - loss: 455.2682 - mean_squared_error: 455.2682
# Epoch 10/300
#  - 0s - loss: 421.5133 - mean_squared_error: 421.5133
# Epoch 11/300
#  - 0s - loss: 384.3367 - mean_squared_error: 384.3367
# Epoch 12/300
#  - 0s - loss: 343.1198 - mean_squared_error: 343.1198
# Epoch 13/300
#  - 0s - loss: 300.5143 - mean_squared_error: 300.5143
# Epoch 14/300
#  - 0s - loss: 257.7569 - mean_squared_error: 257.7569
# Epoch 15/300
#  - 0s - loss: 218.2506 - mean_squared_error: 218.2506
# Epoch 16/300
#  - 0s - loss: 180.9537 - mean_squared_error: 180.9537
# Epoch 17/300
#  - 0s - loss: 148.5161 - mean_squared_error: 148.5161
# Epoch 18/300
#  - 0s - loss: 123.3346 - mean_squared_error: 123.3346
# Epoch 19/300
#  - 0s - loss: 103.0486 - mean_squared_error: 103.0486
# Epoch 20/300
#  - 0s - loss: 86.2203 - mean_squared_error: 86.2203
# Epoch 21/300
#  - 0s - loss: 73.5861 - mean_squared_error: 73.5861
# Epoch 22/300
#  - 0s - loss: 63.3541 - mean_squared_error: 63.3541
# Epoch 23/300
#  - 0s - loss: 55.2369 - mean_squared_error: 55.2369
# Epoch 24/300
#  - 0s - loss: 48.6976 - mean_squared_error: 48.6976
# Epoch 25/300
#  - 0s - loss: 43.4769 - mean_squared_error: 43.4769
# Epoch 26/300
#  - 0s - loss: 39.5002 - mean_squared_error: 39.5002
# Epoch 27/300
#  - 0s - loss: 35.7888 - mean_squared_error: 35.7888
# Epoch 28/300
#  - 0s - loss: 33.2426 - mean_squared_error: 33.2426
# Epoch 29/300
#  - 0s - loss: 30.8819 - mean_squared_error: 30.8819
# Epoch 30/300
#  - 0s - loss: 28.9428 - mean_squared_error: 28.9428
# Epoch 31/300
#  - 0s - loss: 27.4592 - mean_squared_error: 27.4592
# Epoch 32/300
#  - 0s - loss: 26.1222 - mean_squared_error: 26.1222
# Epoch 33/300
#  - 0s - loss: 24.9839 - mean_squared_error: 24.9839
# Epoch 34/300
#  - 0s - loss: 24.1522 - mean_squared_error: 24.1522
# Epoch 35/300
#  - 0s - loss: 23.3220 - mean_squared_error: 23.3220
# Epoch 36/300
#  - 0s - loss: 22.6720 - mean_squared_error: 22.6720
# Epoch 37/300
#  - 0s - loss: 21.9856 - mean_squared_error: 21.9856
# Epoch 38/300
#  - 0s - loss: 21.3934 - mean_squared_error: 21.3934
# Epoch 39/300
#  - 0s - loss: 20.9012 - mean_squared_error: 20.9012
# Epoch 40/300
#  - 0s - loss: 20.4474 - mean_squared_error: 20.4474
# Epoch 41/300
#  - 0s - loss: 20.0066 - mean_squared_error: 20.0066
# Epoch 42/300
#  - 0s - loss: 19.6410 - mean_squared_error: 19.6410
# Epoch 43/300
#  - 0s - loss: 19.3096 - mean_squared_error: 19.3096
# Epoch 44/300
#  - 0s - loss: 19.0084 - mean_squared_error: 19.0084
# Epoch 45/300
#  - 0s - loss: 18.6699 - mean_squared_error: 18.6699
# Epoch 46/300
#  - 0s - loss: 18.3666 - mean_squared_error: 18.3666
# Epoch 47/300
#  - 0s - loss: 18.0881 - mean_squared_error: 18.0881
# Epoch 48/300
#  - 0s - loss: 17.9006 - mean_squared_error: 17.9006
# Epoch 49/300
#  - 0s - loss: 17.6216 - mean_squared_error: 17.6216
# Epoch 50/300
#  - 0s - loss: 17.3994 - mean_squared_error: 17.3994
# Epoch 51/300
#  - 0s - loss: 17.1956 - mean_squared_error: 17.1956
# Epoch 52/300
#  - 0s - loss: 16.9543 - mean_squared_error: 16.9543
# Epoch 53/300
#  - 0s - loss: 16.7587 - mean_squared_error: 16.7587
# Epoch 54/300
#  - 0s - loss: 16.5773 - mean_squared_error: 16.5773
# Epoch 55/300
#  - 0s - loss: 16.3784 - mean_squared_error: 16.3784
# Epoch 56/300
#  - 0s - loss: 16.1960 - mean_squared_error: 16.1960
# Epoch 57/300
#  - 0s - loss: 16.0187 - mean_squared_error: 16.0187
# Epoch 58/300
#  - 0s - loss: 15.8299 - mean_squared_error: 15.8299
# Epoch 59/300
#  - 0s - loss: 15.6641 - mean_squared_error: 15.6641
# Epoch 60/300
#  - 0s - loss: 15.4911 - mean_squared_error: 15.4911
# Epoch 61/300
#  - 0s - loss: 15.2938 - mean_squared_error: 15.2938
# Epoch 62/300
#  - 0s - loss: 15.1467 - mean_squared_error: 15.1467
# Epoch 63/300
#  - 0s - loss: 14.9720 - mean_squared_error: 14.9720
# Epoch 64/300
#  - 0s - loss: 14.8303 - mean_squared_error: 14.8303
# Epoch 65/300
#  - 0s - loss: 14.6736 - mean_squared_error: 14.6736
# Epoch 66/300
#  - 0s - loss: 14.5453 - mean_squared_error: 14.5453
# Epoch 67/300
#  - 0s - loss: 14.3902 - mean_squared_error: 14.3902
# Epoch 68/300
#  - 0s - loss: 14.2616 - mean_squared_error: 14.2616
# Epoch 69/300
#  - 0s - loss: 14.1032 - mean_squared_error: 14.1032
# Epoch 70/300
#  - 0s - loss: 13.9814 - mean_squared_error: 13.9814
# Epoch 71/300
#  - 0s - loss: 13.8705 - mean_squared_error: 13.8705
# Epoch 72/300
#  - 0s - loss: 13.7422 - mean_squared_error: 13.7422
# Epoch 73/300
#  - 0s - loss: 13.6436 - mean_squared_error: 13.6436
# Epoch 74/300
#  - 0s - loss: 13.5331 - mean_squared_error: 13.5331
# Epoch 75/300
#  - 0s - loss: 13.4406 - mean_squared_error: 13.4406
# Epoch 76/300
#  - 0s - loss: 13.3271 - mean_squared_error: 13.3271
# Epoch 77/300
#  - 0s - loss: 13.2278 - mean_squared_error: 13.2278
# Epoch 78/300
#  - 0s - loss: 13.1101 - mean_squared_error: 13.1101
# Epoch 79/300
#  - 0s - loss: 13.0010 - mean_squared_error: 13.0010
# Epoch 80/300
#  - 0s - loss: 12.8814 - mean_squared_error: 12.8814
# Epoch 81/300
#  - 0s - loss: 12.7968 - mean_squared_error: 12.7968
# Epoch 82/300
#  - 0s - loss: 12.6736 - mean_squared_error: 12.6736
# Epoch 83/300
#  - 0s - loss: 12.5767 - mean_squared_error: 12.5767
# Epoch 84/300
#  - 0s - loss: 12.4756 - mean_squared_error: 12.4756
# Epoch 85/300
#  - 0s - loss: 12.3912 - mean_squared_error: 12.3912
# Epoch 86/300
#  - 0s - loss: 12.3112 - mean_squared_error: 12.3112
# Epoch 87/300
#  - 0s - loss: 12.2167 - mean_squared_error: 12.2167
# Epoch 88/300
#  - 0s - loss: 12.1335 - mean_squared_error: 12.1335
# Epoch 89/300
#  - 0s - loss: 12.0376 - mean_squared_error: 12.0376
# Epoch 90/300
#  - 0s - loss: 11.9801 - mean_squared_error: 11.9801
# Epoch 91/300
#  - 0s - loss: 11.8891 - mean_squared_error: 11.8891
# Epoch 92/300
#  - 0s - loss: 11.8082 - mean_squared_error: 11.8082
# Epoch 93/300
#  - 0s - loss: 11.7490 - mean_squared_error: 11.7490
# Epoch 94/300
#  - 0s - loss: 11.6621 - mean_squared_error: 11.6621
# Epoch 95/300
#  - 0s - loss: 11.5722 - mean_squared_error: 11.5722
# Epoch 96/300
#  - 0s - loss: 11.5041 - mean_squared_error: 11.5041
# Epoch 97/300
#  - 0s - loss: 11.4119 - mean_squared_error: 11.4119
# Epoch 98/300
#  - 0s - loss: 11.3665 - mean_squared_error: 11.3665
# Epoch 99/300
#  - 0s - loss: 11.2721 - mean_squared_error: 11.2721
# Epoch 100/300
#  - 0s - loss: 11.2141 - mean_squared_error: 11.2141
# Epoch 101/300
#  - 0s - loss: 11.1368 - mean_squared_error: 11.1368
# Epoch 102/300
#  - 0s - loss: 11.0847 - mean_squared_error: 11.0847
# Epoch 103/300
#  - 0s - loss: 10.9969 - mean_squared_error: 10.9969
# Epoch 104/300
#  - 0s - loss: 10.9408 - mean_squared_error: 10.9408
# Epoch 105/300
#  - 0s - loss: 10.8813 - mean_squared_error: 10.8813
# Epoch 106/300
#  - 0s - loss: 10.8078 - mean_squared_error: 10.8078
# Epoch 107/300
#  - 0s - loss: 10.7619 - mean_squared_error: 10.7619
# Epoch 108/300
#  - 0s - loss: 10.6900 - mean_squared_error: 10.6900
# Epoch 109/300
#  - 0s - loss: 10.6278 - mean_squared_error: 10.6278
# Epoch 110/300
#  - 0s - loss: 10.5665 - mean_squared_error: 10.5665
# Epoch 111/300
#  - 0s - loss: 10.5040 - mean_squared_error: 10.5040
# Epoch 112/300
#  - 0s - loss: 10.4888 - mean_squared_error: 10.4888
# Epoch 113/300
#  - 0s - loss: 10.4093 - mean_squared_error: 10.4093
# Epoch 114/300
#  - 0s - loss: 10.3331 - mean_squared_error: 10.3331
# Epoch 115/300
#  - 0s - loss: 10.2657 - mean_squared_error: 10.2657
# Epoch 116/300
#  - 0s - loss: 10.2124 - mean_squared_error: 10.2124
# Epoch 117/300
#  - 0s - loss: 10.1555 - mean_squared_error: 10.1555
# Epoch 118/300
#  - 0s - loss: 10.0922 - mean_squared_error: 10.0922
# Epoch 119/300
#  - 0s - loss: 10.0568 - mean_squared_error: 10.0568
# Epoch 120/300
#  - 0s - loss: 9.9806 - mean_squared_error: 9.9806
# Epoch 121/300
#  - 0s - loss: 9.9333 - mean_squared_error: 9.9333
# Epoch 122/300
#  - 0s - loss: 9.8947 - mean_squared_error: 9.8947
# Epoch 123/300
#  - 0s - loss: 9.8482 - mean_squared_error: 9.8482
# Epoch 124/300
#  - 0s - loss: 9.8083 - mean_squared_error: 9.8083
# Epoch 125/300
#  - 0s - loss: 9.7366 - mean_squared_error: 9.7366
# Epoch 126/300
#  - 0s - loss: 9.6733 - mean_squared_error: 9.6733
# Epoch 127/300
#  - 0s - loss: 9.6725 - mean_squared_error: 9.6725
# Epoch 128/300
#  - 0s - loss: 9.6171 - mean_squared_error: 9.6171
# Epoch 129/300
#  - 0s - loss: 9.5502 - mean_squared_error: 9.5502
# Epoch 130/300
#  - 0s - loss: 9.5052 - mean_squared_error: 9.5052
# Epoch 131/300
#  - 0s - loss: 9.4817 - mean_squared_error: 9.4817
# Epoch 132/300
#  - 0s - loss: 9.4962 - mean_squared_error: 9.4962
# Epoch 133/300
#  - 0s - loss: 9.3654 - mean_squared_error: 9.3654
# Epoch 134/300
#  - 0s - loss: 9.2951 - mean_squared_error: 9.2951
# Epoch 135/300
#  - 0s - loss: 9.2302 - mean_squared_error: 9.2302
# Epoch 136/300
#  - 0s - loss: 9.2230 - mean_squared_error: 9.2230
# Epoch 137/300
#  - 0s - loss: 9.1692 - mean_squared_error: 9.1692
# Epoch 138/300
#  - 0s - loss: 9.0899 - mean_squared_error: 9.0899
# Epoch 139/300
#  - 0s - loss: 9.0546 - mean_squared_error: 9.0546
# Epoch 140/300
#  - 0s - loss: 9.0064 - mean_squared_error: 9.0064
# Epoch 141/300
#  - 0s - loss: 8.9581 - mean_squared_error: 8.9581
# Epoch 142/300
#  - 0s - loss: 8.9086 - mean_squared_error: 8.9086
# Epoch 143/300
#  - 0s - loss: 8.8812 - mean_squared_error: 8.8812
# Epoch 144/300
#  - 0s - loss: 8.8412 - mean_squared_error: 8.8412
# Epoch 145/300
#  - 0s - loss: 8.7848 - mean_squared_error: 8.7848
# Epoch 146/300
#  - 0s - loss: 8.7401 - mean_squared_error: 8.7401
# Epoch 147/300
#  - 0s - loss: 8.7071 - mean_squared_error: 8.7071
# Epoch 148/300
#  - 0s - loss: 8.6746 - mean_squared_error: 8.6746
# Epoch 149/300
#  - 0s - loss: 8.6416 - mean_squared_error: 8.6416
# Epoch 150/300
#  - 0s - loss: 8.5915 - mean_squared_error: 8.5915
# Epoch 151/300
#  - 0s - loss: 8.5457 - mean_squared_error: 8.5457
# Epoch 152/300
#  - 0s - loss: 8.5156 - mean_squared_error: 8.5156
# Epoch 153/300
#  - 0s - loss: 8.4744 - mean_squared_error: 8.4744
# Epoch 154/300
#  - 0s - loss: 8.4437 - mean_squared_error: 8.4437
# Epoch 155/300
#  - 0s - loss: 8.3982 - mean_squared_error: 8.3982
# Epoch 156/300
#  - 0s - loss: 8.3927 - mean_squared_error: 8.3927
# Epoch 157/300
#  - 0s - loss: 8.3243 - mean_squared_error: 8.3243
# Epoch 158/300
#  - 0s - loss: 8.3083 - mean_squared_error: 8.3083
# Epoch 159/300
#  - 0s - loss: 8.2403 - mean_squared_error: 8.2403
# Epoch 160/300
#  - 0s - loss: 8.2121 - mean_squared_error: 8.2121
# Epoch 161/300
#  - 0s - loss: 8.2000 - mean_squared_error: 8.2000
# Epoch 162/300
#  - 0s - loss: 8.1491 - mean_squared_error: 8.1491
# Epoch 163/300
#  - 0s - loss: 8.1029 - mean_squared_error: 8.1029
# Epoch 164/300
#  - 0s - loss: 8.0872 - mean_squared_error: 8.0872
# Epoch 165/300
#  - 0s - loss: 8.0265 - mean_squared_error: 8.0265
# Epoch 166/300
#  - 0s - loss: 7.9860 - mean_squared_error: 7.9860
# Epoch 167/300
#  - 0s - loss: 7.9516 - mean_squared_error: 7.9516
# Epoch 168/300
#  - 0s - loss: 7.9407 - mean_squared_error: 7.9407
# Epoch 169/300
#  - 0s - loss: 7.8841 - mean_squared_error: 7.8841
# Epoch 170/300
#  - 0s - loss: 7.8856 - mean_squared_error: 7.8856
# Epoch 171/300
#  - 0s - loss: 7.8523 - mean_squared_error: 7.8523
# Epoch 172/300
#  - 0s - loss: 7.7961 - mean_squared_error: 7.7961
# Epoch 173/300
#  - 0s - loss: 7.7552 - mean_squared_error: 7.7552
# Epoch 174/300
#  - 0s - loss: 7.7291 - mean_squared_error: 7.7291
# Epoch 175/300
#  - 0s - loss: 7.6879 - mean_squared_error: 7.6879
# Epoch 176/300
#  - 0s - loss: 7.6558 - mean_squared_error: 7.6558
# Epoch 177/300
#  - 0s - loss: 7.6338 - mean_squared_error: 7.6338
# Epoch 178/300
#  - 0s - loss: 7.5820 - mean_squared_error: 7.5820
# Epoch 179/300
#  - 0s - loss: 7.5479 - mean_squared_error: 7.5479
# Epoch 180/300
#  - 0s - loss: 7.5287 - mean_squared_error: 7.5287
# Epoch 181/300
#  - 0s - loss: 7.4974 - mean_squared_error: 7.4974
# Epoch 182/300
#  - 0s - loss: 7.4696 - mean_squared_error: 7.4696
# Epoch 183/300
#  - 0s - loss: 7.4322 - mean_squared_error: 7.4322
# Epoch 184/300
#  - 0s - loss: 7.4068 - mean_squared_error: 7.4068
# Epoch 185/300
#  - 0s - loss: 7.3687 - mean_squared_error: 7.3687
# Epoch 186/300
#  - 0s - loss: 7.3586 - mean_squared_error: 7.3586
# Epoch 187/300
#  - 0s - loss: 7.3063 - mean_squared_error: 7.3063
# Epoch 188/300
#  - 0s - loss: 7.2896 - mean_squared_error: 7.2896
# Epoch 189/300
#  - 0s - loss: 7.2970 - mean_squared_error: 7.2970
# Epoch 190/300
#  - 0s - loss: 7.2176 - mean_squared_error: 7.2176
# Epoch 191/300
#  - 0s - loss: 7.1907 - mean_squared_error: 7.1907
# Epoch 192/300
#  - 0s - loss: 7.1672 - mean_squared_error: 7.1672
# Epoch 193/300
#  - 0s - loss: 7.1184 - mean_squared_error: 7.1184
# Epoch 194/300
#  - 0s - loss: 7.0961 - mean_squared_error: 7.0961
# Epoch 195/300
#  - 0s - loss: 7.0642 - mean_squared_error: 7.0642
# Epoch 196/300
#  - 0s - loss: 7.0438 - mean_squared_error: 7.0438
# Epoch 197/300
#  - 0s - loss: 6.9999 - mean_squared_error: 6.9999
# Epoch 198/300
#  - 0s - loss: 6.9885 - mean_squared_error: 6.9885
# Epoch 199/300
#  - 0s - loss: 6.9446 - mean_squared_error: 6.9446
# Epoch 200/300
#  - 0s - loss: 6.9477 - mean_squared_error: 6.9477
# Epoch 201/300
#  - 0s - loss: 6.9096 - mean_squared_error: 6.9096
# Epoch 202/300
#  - 0s - loss: 6.8763 - mean_squared_error: 6.8763
# Epoch 203/300
#  - 0s - loss: 6.8487 - mean_squared_error: 6.8487
# Epoch 204/300
#  - 0s - loss: 6.8113 - mean_squared_error: 6.8113
# Epoch 205/300
#  - 0s - loss: 6.7743 - mean_squared_error: 6.7743
# Epoch 206/300
#  - 0s - loss: 6.7602 - mean_squared_error: 6.7602
# Epoch 207/300
#  - 0s - loss: 6.7347 - mean_squared_error: 6.7347
# Epoch 208/300
#  - 0s - loss: 6.7009 - mean_squared_error: 6.7009
# Epoch 209/300
#  - 0s - loss: 6.7023 - mean_squared_error: 6.7023
# Epoch 210/300
#  - 0s - loss: 6.6702 - mean_squared_error: 6.6702
# Epoch 211/300
#  - 0s - loss: 6.5951 - mean_squared_error: 6.5951
# Epoch 212/300
#  - 0s - loss: 6.5823 - mean_squared_error: 6.5823
# Epoch 213/300
#  - 0s - loss: 6.5623 - mean_squared_error: 6.5623
# Epoch 214/300
#  - 0s - loss: 6.5249 - mean_squared_error: 6.5249
# Epoch 215/300
#  - 0s - loss: 6.4849 - mean_squared_error: 6.4849
# Epoch 216/300
#  - 0s - loss: 6.4520 - mean_squared_error: 6.4520
# Epoch 217/300
#  - 0s - loss: 6.4508 - mean_squared_error: 6.4508
# Epoch 218/300
#  - 0s - loss: 6.4228 - mean_squared_error: 6.4228
# Epoch 219/300
#  - 0s - loss: 6.3838 - mean_squared_error: 6.3838
# Epoch 220/300
#  - 0s - loss: 6.3609 - mean_squared_error: 6.3609
# Epoch 221/300
#  - 0s - loss: 6.3183 - mean_squared_error: 6.3183
# Epoch 222/300
#  - 0s - loss: 6.2908 - mean_squared_error: 6.2908
# Epoch 223/300
#  - 0s - loss: 6.2630 - mean_squared_error: 6.2630
# Epoch 224/300
#  - 0s - loss: 6.2422 - mean_squared_error: 6.2422
# Epoch 225/300
#  - 0s - loss: 6.2232 - mean_squared_error: 6.2232
# Epoch 226/300
#  - 0s - loss: 6.2092 - mean_squared_error: 6.2092
# Epoch 227/300
#  - 0s - loss: 6.1961 - mean_squared_error: 6.1961
# Epoch 228/300
#  - 0s - loss: 6.1449 - mean_squared_error: 6.1449
# Epoch 229/300
#  - 0s - loss: 6.1127 - mean_squared_error: 6.1127
# Epoch 230/300
#  - 0s - loss: 6.0916 - mean_squared_error: 6.0916
# Epoch 231/300
#  - 0s - loss: 6.0726 - mean_squared_error: 6.0726
# Epoch 232/300
#  - 0s - loss: 6.0582 - mean_squared_error: 6.0582
# Epoch 233/300
#  - 0s - loss: 6.0173 - mean_squared_error: 6.0173
# Epoch 234/300
#  - 0s - loss: 5.9803 - mean_squared_error: 5.9803
# Epoch 235/300
#  - 0s - loss: 6.0080 - mean_squared_error: 6.0080
# Epoch 236/300
#  - 0s - loss: 5.9477 - mean_squared_error: 5.9477
# Epoch 237/300
#  - 0s - loss: 5.9332 - mean_squared_error: 5.9332
# Epoch 238/300
#  - 0s - loss: 5.9197 - mean_squared_error: 5.9197
# Epoch 239/300
#  - 0s - loss: 5.8704 - mean_squared_error: 5.8704
# Epoch 240/300
#  - 0s - loss: 5.8457 - mean_squared_error: 5.8457
# Epoch 241/300
#  - 0s - loss: 5.8285 - mean_squared_error: 5.8285
# Epoch 242/300
#  - 0s - loss: 5.8133 - mean_squared_error: 5.8133
# Epoch 243/300
#  - 0s - loss: 5.7935 - mean_squared_error: 5.7935
# Epoch 244/300
#  - 0s - loss: 5.7791 - mean_squared_error: 5.7791
# Epoch 245/300
#  - 0s - loss: 5.7461 - mean_squared_error: 5.7461
# Epoch 246/300
#  - 0s - loss: 5.7465 - mean_squared_error: 5.7465
# Epoch 247/300
#  - 0s - loss: 5.7584 - mean_squared_error: 5.7584
# Epoch 248/300
#  - 0s - loss: 5.6890 - mean_squared_error: 5.6890
# Epoch 249/300
#  - 0s - loss: 5.6727 - mean_squared_error: 5.6727
# Epoch 250/300
#  - 0s - loss: 5.6296 - mean_squared_error: 5.6296
# Epoch 251/300
#  - 0s - loss: 5.6192 - mean_squared_error: 5.6192
# Epoch 252/300
#  - 0s - loss: 5.5896 - mean_squared_error: 5.5896
# Epoch 253/300
#  - 0s - loss: 5.5617 - mean_squared_error: 5.5617
# Epoch 254/300
#  - 0s - loss: 5.5577 - mean_squared_error: 5.5577
# Epoch 255/300
#  - 0s - loss: 5.5235 - mean_squared_error: 5.5235
# Epoch 256/300
#  - 0s - loss: 5.5094 - mean_squared_error: 5.5094
# Epoch 257/300
#  - 0s - loss: 5.4806 - mean_squared_error: 5.4806
# Epoch 258/300
#  - 0s - loss: 5.5269 - mean_squared_error: 5.5269
# Epoch 259/300
#  - 0s - loss: 5.4944 - mean_squared_error: 5.4944
# Epoch 260/300
#  - 0s - loss: 5.4379 - mean_squared_error: 5.4379
# Epoch 261/300
#  - 0s - loss: 5.4347 - mean_squared_error: 5.4347
# Epoch 262/300
#  - 0s - loss: 5.4090 - mean_squared_error: 5.4090
# Epoch 263/300
#  - 0s - loss: 5.3830 - mean_squared_error: 5.3830
# Epoch 264/300
#  - 0s - loss: 5.3767 - mean_squared_error: 5.3767
# Epoch 265/300
#  - 0s - loss: 5.3591 - mean_squared_error: 5.3591
# Epoch 266/300
#  - 0s - loss: 5.3801 - mean_squared_error: 5.3801
# Epoch 267/300
#  - 0s - loss: 5.3514 - mean_squared_error: 5.3514
# Epoch 268/300
#  - 0s - loss: 5.3363 - mean_squared_error: 5.3363
# Epoch 269/300
#  - 0s - loss: 5.3688 - mean_squared_error: 5.3688
# Epoch 270/300
#  - 0s - loss: 5.2704 - mean_squared_error: 5.2704
# Epoch 271/300
#  - 0s - loss: 5.2742 - mean_squared_error: 5.2742
# Epoch 272/300
#  - 0s - loss: 5.2171 - mean_squared_error: 5.2171
# Epoch 273/300
#  - 0s - loss: 5.2202 - mean_squared_error: 5.2202
# Epoch 274/300
#  - 0s - loss: 5.2275 - mean_squared_error: 5.2275
# Epoch 275/300
#  - 0s - loss: 5.1970 - mean_squared_error: 5.1970
# Epoch 276/300
#  - 0s - loss: 5.1519 - mean_squared_error: 5.1519
# Epoch 277/300
#  - 0s - loss: 5.1574 - mean_squared_error: 5.1574
# Epoch 278/300
#  - 0s - loss: 5.1408 - mean_squared_error: 5.1408
# Epoch 279/300
#  - 0s - loss: 5.1240 - mean_squared_error: 5.1240
# Epoch 280/300
#  - 0s - loss: 5.1256 - mean_squared_error: 5.1256
# Epoch 281/300
#  - 0s - loss: 5.0929 - mean_squared_error: 5.0929
# Epoch 282/300
#  - 0s - loss: 5.0674 - mean_squared_error: 5.0674
# Epoch 283/300
#  - 0s - loss: 5.0639 - mean_squared_error: 5.0639
# Epoch 284/300
#  - 0s - loss: 5.0636 - mean_squared_error: 5.0636
# Epoch 285/300
#  - 0s - loss: 5.0221 - mean_squared_error: 5.0221
# Epoch 286/300
#  - 0s - loss: 4.9977 - mean_squared_error: 4.9977
# Epoch 287/300
#  - 0s - loss: 4.9971 - mean_squared_error: 4.9971
# Epoch 288/300
#  - 0s - loss: 4.9620 - mean_squared_error: 4.9620
# Epoch 289/300
#  - 0s - loss: 4.9606 - mean_squared_error: 4.9606
# Epoch 290/300
#  - 0s - loss: 4.9503 - mean_squared_error: 4.9503
# Epoch 291/300
#  - 0s - loss: 4.9282 - mean_squared_error: 4.9282
# Epoch 292/300
#  - 0s - loss: 4.9202 - mean_squared_error: 4.9202
# Epoch 293/300
#  - 0s - loss: 4.9207 - mean_squared_error: 4.9207
# Epoch 294/300
#  - 0s - loss: 4.9164 - mean_squared_error: 4.9164
# Epoch 295/300
#  - 0s - loss: 4.9022 - mean_squared_error: 4.9022
# Epoch 296/300
#  - 0s - loss: 4.8474 - mean_squared_error: 4.8474
# Epoch 297/300
#  - 0s - loss: 4.8698 - mean_squared_error: 4.8698
# Epoch 298/300
#  - 0s - loss: 4.8440 - mean_squared_error: 4.8440
# Epoch 299/300
#  - 0s - loss: 4.8320 - mean_squared_error: 4.8320
# Epoch 300/300
#  - 0s - loss: 4.8134 - mean_squared_error: 4.8134

# %%
model.predict(prediction_input_preprocessor.transform(X_test))
# Out:
# array([[26.220055 ],
#        [32.73987  ],
#        [16.173426 ],
#        [25.706514 ],
#        [15.464637 ],
#        [20.720594 ],
#        [17.258877 ],
#        [14.580169 ],
#        [26.640337 ],
#        [20.191103 ],
#        [21.067207 ],
#        [18.692995 ],
#        [ 6.6557207],
#        [19.44738  ],
#        [17.542326 ],
#        [23.82765  ],
#        [20.26005  ],
#        [ 9.502681 ],
#        [43.94678  ],
#        [14.034834 ],
#        [27.90777  ],
#        [27.687216 ],
#        [14.020556 ],
#        [19.54783  ],
#        [16.616287 ],
#        [17.027983 ],
#        [19.742914 ],
#        [12.544759 ],
#        [22.059595 ],
#        [19.02437  ],
#        [20.18059  ],
#        [23.53734  ],
#        [21.1074   ],
#        [25.902506 ],
#        [12.6835985],
#        [15.6026   ],
#        [30.20878  ],
#        [19.688906 ],
#        [21.409513 ],
#        [25.797617 ],
#        [14.893276 ],
#        [29.121069 ],
#        [47.370842 ],
#        [19.042418 ],
#        [23.504293 ],
#        [16.238457 ],
#        [15.593864 ],
#        [27.221012 ],
#        [18.42625  ],
#        [24.4611   ],
#        [19.703405 ],
#        [36.327732 ],
#        [16.918987 ],
#        [24.951664 ],
#        [43.648117 ],
#        [22.576094 ],
#        [16.594542 ],
#        [33.180298 ],
#        [25.066813 ],
#        [13.670648 ],
#        [25.447256 ],
#        [35.267944 ],
#        [32.766    ],
#        [18.053885 ],
#        [21.858538 ],
#        [19.550016 ],
#        [17.178782 ],
#        [24.446218 ],
#        [31.872486 ],
#        [12.609429 ],
#        [21.32121  ],
#        [28.505636 ],
#        [ 8.850226 ],
#        [21.383554 ],
#        [21.00001  ],
#        [ 7.047024 ],
#        [20.704985 ],
#        [44.521214 ],
#        [12.750291 ],
#        [11.429974 ],
#        [20.434391 ],
#        [11.488253 ],
#        [19.10422  ],
#        [10.867579 ],
#        [20.7534   ],
#        [27.580397 ],
#        [14.850318 ],
#        [24.008772 ],
#        [25.405294 ],
#        [19.211271 ],
#        [22.81589  ],
#        [ 8.239874 ],
#        [20.021097 ],
#        [17.205318 ],
#        [33.82628  ],
#        [21.3456   ],
#        [32.31211  ],
#        [10.831346 ],
#        [12.445487 ],
#        [12.4423685],
#        [23.04608  ],
#        [21.663565 ],
#        [10.64413  ],
#        [19.708063 ],
#        [18.122396 ],
#        [10.537484 ],
#        [19.366411 ],
#        [25.733671 ],
#        [20.667913 ],
#        [23.265524 ],
#        [ 8.35345  ],
#        [14.067317 ],
#        [21.962204 ],
#        [27.637518 ],
#        [31.260786 ],
#        [14.591468 ],
#        [41.5224   ],
#        [13.953212 ],
#        [21.987055 ],
#        [25.78668  ],
#        [15.151017 ],
#        [26.114004 ],
#        [ 4.0764008],
#        [21.059351 ],
#        [26.757303 ],
#        [20.636398 ],
#        [23.311256 ]], dtype=float32)

# %%
import numpy as np
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
import pandas as pd
from math import sqrt


def model_eval_metrics(y_true, y_pred,classification="TRUE"):
     if classification=="TRUE":
        accuracy_eval = accuracy_score(y_true, y_pred)
        f1_score_eval = f1_score(y_true, y_pred,average="macro",zero_division=0)
        precision_eval = precision_score(y_true, y_pred,average="macro",zero_division=0)
        recall_eval = recall_score(y_true, y_pred,average="macro",zero_division=0)
        mse_eval = 0
        rmse_eval = 0
        mae_eval = 0
        r2_eval = 0
        metricdata = {'accuracy': [accuracy_eval], 'f1_score': [f1_score_eval], 'precision': [precision_eval], 'recall': [recall_eval], 'mse': [mse_eval], 'rmse': [rmse_eval], 'mae': [mae_eval], 'r2': [r2_eval]}
        finalmetricdata = pd.DataFrame.from_dict(metricdata)
     else:
        accuracy_eval = 0
        f1_score_eval = 0
        precision_eval = 0
        recall_eval = 0
        mse_eval = mean_squared_error(y_true, y_pred)
        rmse_eval = sqrt(mean_squared_error(y_true, y_pred))
        mae_eval = mean_absolute_error(y_true, y_pred)
        r2_eval = r2_score(y_true, y_pred)
        metricdata = {'accuracy': [accuracy_eval], 'f1_score': [f1_score_eval], 'precision': [precision_eval], 'recall': [recall_eval], 'mse': [mse_eval], 'rmse': [rmse_eval], 'mae': [mae_eval], 'r2': [r2_eval]}
        finalmetricdata = pd.DataFrame.from_dict(metricdata)
     return finalmetricdata

model_eval_metrics( y_test,model.predict(prediction_input_preprocessor.transform(X_test)),classification="FALSE")
# Out:
#    accuracy  f1_score  precision  ...     rmse       mae        r2
# 0         0         0          0  ...  3.31834  2.197845  0.824729
#
# [1 rows x 8 columns]

# %%
modelevalobject=model_eval_metrics( y_test,model.predict(prediction_input_preprocessor.transform(X_test)),classification="FALSE")

# %%
! pip3 install keras2onnx
! pip3 install onnxruntime
# Out:
# Collecting keras2onnx
#   Downloading https://files.pythonhosted.org/packages/60/df/38475abd5ef1e0c5a19f021add159e8a07d10525b2c01f13bf06371aedd4/keras2onnx-1.6.0-py3-none-any.whl (219kB)
#      |████████████████████████████████| 225kB 9.3MB/s
# Collecting onnxconverter-common>=1.6.0
#   Downloading https://files.pythonhosted.org/packages/77/3d/6112c19223d1eabbedf1b063567034e1463a11d7c82d1820f26b75d14e3c/onnxconverter_common-1.6.0-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 7.2MB/s
# Collecting onnx
#   Downloading https://files.pythonhosted.org/packages/f5/f4/e126b60d109ad1e80020071484b935980b7cce1e4796073aab086a2d6902/onnx-1.6.0-cp36-cp36m-manylinux1_x86_64.whl (4.8MB)
#      |████████████████████████████████| 4.8MB 19.8MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from keras2onnx) (1.17.5)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from keras2onnx) (3.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from keras2onnx) (2.21.0)
# Collecting fire
#   Downloading https://files.pythonhosted.org/packages/d9/69/faeaae8687f4de0f5973694d02e9d6c3eb827636a009157352d98de1129e/fire-0.2.1.tar.gz (76kB)
#      |████████████████████████████████| 81kB 11.3MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from onnxconverter-common>=1.6.0->keras2onnx) (1.12.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /usr/local/lib/python3.6/dist-packages (from onnx->keras2onnx) (3.6.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->keras2onnx) (42.0.2)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->keras2onnx) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->keras2onnx) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->keras2onnx) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->keras2onnx) (2019.11.28)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.6/dist-packages (from fire->keras2onnx) (1.1.0)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.2.1-py2.py3-none-any.whl size=103527 sha256=2640c5b72409a0595f46d52d359a01447991c5bc1221452dc684ac3043385fb7
#   Stored in directory: /root/.cache/pip/wheels/31/9c/c0/07b6dc7faf1844bb4688f46b569efe6cafaa2179c95db821da
# Successfully built fire
# Installing collected packages: onnx, onnxconverter-common, fire, keras2onnx
# Successfully installed fire-0.2.1 keras2onnx-1.6.0 onnx-1.6.0 onnxconverter-common-1.6.0
# Collecting onnxruntime
#   Downloading https://files.pythonhosted.org/packages/3b/13/1ac0397bcffb30d03af3de80eae9b960883d2e43e3a562423260948390f5/onnxruntime-1.1.1-cp36-cp36m-manylinux1_x86_64.whl (3.6MB)
#      |████████████████████████████████| 3.6MB 9.5MB/s
# Installing collected packages: onnxruntime
# Successfully installed onnxruntime-1.1.1

# %%
#Convert keras model object to onnx and then save it to .onnx file
import os

if not os.path.exists('mymodel.onnx'):
    from keras2onnx import convert_keras
    onx = convert_keras(model, 'mymodel.onnx')
    with open("mymodel.onnx", "wb") as f:
        f.write(onx.SerializeToString())
# Out:
# The maximum opset needed by this model is only 9.

# %%
#install aimodelshare library
! pip3 install https://github.com/mikedparrott/aimodelshare/blob/master/aimodelshare-0.0.2.tar.gz?raw=true
# Out:
# Collecting https://github.com/mikedparrott/aimodelshare/blob/master/aimodelshare-0.0.2.tar.gz?raw=true
#   Using cached https://github.com/mikedparrott/aimodelshare/blob/master/aimodelshare-0.0.2.tar.gz?raw=true
# Requirement already satisfied (use --upgrade to upgrade): aimodelshare==0.0.2 from https://github.com/mikedparrott/aimodelshare/blob/master/aimodelshare-0.0.2.tar.gz?raw=true in /usr/local/lib/python3.6/dist-packages
# Building wheels for collected packages: aimodelshare
#   Building wheel for aimodelshare (setup.py) ... done
#   Created wheel for aimodelshare: filename=aimodelshare-0.0.2-cp36-none-any.whl size=5375 sha256=51c26b0edf85ce8f0224c44f7578f70a5f977e8ef376b872bbdb8702683ca564
#   Stored in directory: /root/.cache/pip/wheels/31/8d/ac/09cb6ef7374ec79e02843c347195e5478144006b11def6799a
# Successfully built aimodelshare

# %% [markdown]
# Sign up for username and password at:
# [AI Model Share Initiative Site](http://mlsitetest.com.s3-website-us-east-1.amazonaws.com/login)
